# %% [markdown]
# <a href="https://colab.research.google.com/github/Yevhenii-Taran-9/Machine-Learning/blob/main/%D0%A2%D0%B0%D1%80%D0%B0%D0%BD_%D0%BF%D1%80_1_%D1%87%D0%B0%D1%81%D1%82%D0%B8%D0%BD%D0%B0_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.__version__
# Out:
# '2.0.2'

# %% [markdown]
# 1. Задати вектор, що складається з перших п'яти натуральних чисел

# %%
vector = np.array([1, 2, 3, 4, 5])

vector
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# 2. Транспонувати вектор

# %%
v1 = np.matrix([1, 2, 3, 4, 5])

print(v1)
v2 = v1.T
v2
# Out:
# [[1 2 3 4 5]]
# matrix([[1],
#         [2],
#         [3],
#         [4],
#         [5]])

# %% [markdown]
# 3. Напишіть функцію, яка перевертає вектор у зворотному порядку

# %%
v = np.array([1, 2, 3, 4, 5])

print(v[::-1])
# Out:
# [5 4 3 2 1]

# %%
v = np.flip(v)

print(v)
# Out:
# [5 4 3 2 1]

# %% [markdown]
# 4. Обчислити середнє значення вектора

# %%
print(np.mean(v))
# Out:
# 3.0

# %% [markdown]
# 5. Знайти найбільший і найменший елементи вектора

# %%
print(np.max(v))
print(np.min(v))
# Out:
# 5
# 1

# %% [markdown]
# 6. Обчислити скалярний добуток (dot product) двох векторів

# %%
v1 = np.array([1, 2, 3])
v2 = np.array([1, 2, 3])

print(np.dot(v1, v2))
print(v1*v2)
# Out:
# 14
# [1 4 9]

# %% [markdown]
# 7. Напишіть функцію, яка нормалізує вектор (зводить до одиничної довжини)

# %%
v = np.array([1, 2, 3, 4, 5])
norm = np.linalg.norm(v)

print(norm)

v/norm
# Out:
# 7.416198487095663
# array([0.13483997, 0.26967994, 0.40451992, 0.53935989, 0.67419986])

# %% [markdown]
# 8. Задати два вектори. Визначте, чи є вони ортогональними. Підказка: якщо скалярний добуток дорівнює нулю, вектори ортогональні.

# %%
v1 = np.array([1, 0, 0])
v2 = np.array([0, 1, 0])

np.dot(v1, v2)
# Out:
# np.int64(0)

# %% [markdown]
# 9. Визначити унікальні елементи вектора

# %%
v = np.array([1, 2, 3, 2, 4, 5, 3])

np.unique(v)
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# 10. Знайти вектори

# %%
v1 = np.array([1, 2, 3])
v2 = np.array([4, 5, 6])

print(v1 - v2)
print(v2 - v1)
print(v1 + v2)
print(v2 + v1)
print(v1 * v2)
print(v2 * v1)
print(v1 / v2)
print(v2 / v1)
# Out:
# [-3 -3 -3]
# [3 3 3]
# [5 7 9]
# [5 7 9]
# [ 4 10 18]
# [ 4 10 18]
# [0.25 0.4  0.5 ]
# [4.  2.5 2. ]

# %% [markdown]
# 11. Перевірити, чи дорівнює довжина вектора 5

# %%
vector = np.array([1, 2, 3, 4, 5])
length = np.linalg.norm(vector)

np.isclose(length, 5)
# Out:
# np.False_

# %% [markdown]
# 12. Задати матрицю, заповнену випадковими числами

# %%
a = np.random.randint (0, 11,  (3, 3))

a
# Out:
# array([[10,  9,  9],
#        [ 7,  7,  6],
#        [ 9, 10,  0]])

# %% [markdown]
# 13.  Обчислити визначник матриці

# %%
np.linalg.det(a)
# Out:
# np.float64(-50.99999999999993)

# %% [markdown]
# 14. Знаходження оберненої матриці

# %%
np.linalg.inv(a)
# Out:
# array([[ 1.17647059, -1.76470588,  0.17647059],
#        [-1.05882353,  1.58823529, -0.05882353],
#        [-0.1372549 ,  0.37254902, -0.1372549 ]])

# %% [markdown]
# 15. Розв'яжіть систему лінійних рівнянь A*x=b, де A - матриця коефіцієнтів, b - вектор вільних членів.

# %%
a = np.array([[1, 3, -4], [0, 2, -3], [-2, 2, 5]])
b = np.array([5, 3, 4])

x = np.linalg.solve(a, b)
print(x)

inv_a = np.linalg.inv(a)
x1 = inv_a.dot(b)
print(x1)
# Out:
# [0.38888889 1.83333333 0.22222222]
# [0.38888889 1.83333333 0.22222222]

# %% [markdown]
# 16. Множення двох матриць

# %%
a = np.array([[1, 3, -4], [0, 2, -3], [-2, 2, 5]])
b = np.array([5, 3, 4])

np.dot(a, b)
# Out:
# array([-2, -6, 16])

# %%
a = np.matrix([[1, 3, -4], [0, 2, -3]])
b = np.matrix([[5, 3, 4], [2, 3, 5], [3, 2, 3]])
print(a)
print(b)
print(np.dot(a, b))
# Out:
# [[ 1  3 -4]
#  [ 0  2 -3]]
# [[5 3 4]
#  [2 3 5]
#  [3 2 3]]
# [[-1  4  7]
#  [-5  0  1]]

# %% [markdown]
# 17. Транспонування матриці

# %%
print(a.T)
print(b.T)
# Out:
# [[ 1  0]
#  [ 3  2]
#  [-4 -3]]
# [[5 2 3]
#  [3 3 2]
#  [4 5 3]]

# %%
print(np.transpose(a))
print(np.transpose(b))
# Out:
# [[ 1  0]
#  [ 3  2]
#  [-4 -3]]
# [[5 2 3]
#  [3 3 2]
#  [4 5 3]]

# %% [markdown]
# 18. Перевірка симетричності матриці

# %%
matrix = np.matrix([[2, 2, 2], [2, 2, 2], [2, 2, 2]])

np.allclose(matrix, matrix.T)
# Out:
# True

# %% [markdown]
# 19. Обчислення сліду матриці

# %%
np.trace(matrix)
# Out:
# np.int64(6)

# %% [markdown]
# 20. Сума матриць

# %%
a = np.matrix([[1, 2], [3, 4]])
b = np.matrix([[5, 6], [7, 8]])

print(np.add(a, b))
print(np.subtract(a, b))
print(np.multiply(a, b))
print(np.divide(a, b))
# Out:
# [[ 6  8]
#  [10 12]]
# [[-4 -4]
#  [-4 -4]]
# [[ 5 12]
#  [21 32]]
# [[0.2        0.33333333]
#  [0.42857143 0.5       ]]

# %% [markdown]
# 21. Піднесення матриці до ступеня

# %%
a = np.matrix([[1, 2], [3, 4]])

np.linalg.matrix_power(a, 2)
# Out:
# matrix([[ 7, 10],
#         [15, 22]])

# %% [markdown]
# 22. Сортування рядків або стовпців матриці

# %%
b = np.matrix([[5, 3, 4], [2, 3, 5], [3, 2, 3]])

print(b)
print(np.sort(b, axis=0))
print(np.sort(b, axis=1))
print(np.sort(b, axis=None))
# Out:
# [[5 3 4]
#  [2 3 5]
#  [3 2 3]]
# [[2 2 3]
#  [3 3 4]
#  [5 3 5]]
# [[3 4 5]
#  [2 3 5]
#  [2 3 3]]
# [[2 2 3 3 3 3 4 5 5]]

# %%
a = np.array([[1, 4], [3, 1]])

print(a)
print(np.sort(a))
# Out:
# [[1 4]
#  [3 1]]
# [[1 4]
#  [1 3]]

# %%
print(np.sort(a, axis=0))
print(np.sort(a, axis=1))
# Out:
# [[1 1]
#  [3 4]]
# [[1 4]
#  [1 3]]

# %% [markdown]
# 23. Підрахувати суму елементів кожного рядка матриці. Відповідь запиши, як вектор-стовпчик

# %%
row_sums = np.sum(a, axis=1).reshape(-1, 1)

print("Сума елементів кожного рядка: ")
print(row_sums)
# Out:
# Сума елементів кожного рядка:
# [[5]
#  [4]]

# %% [markdown]
# # Висновки

# %% [markdown]
# ### У цій лабораторній я детально пропрацював основні операції з векторами й матрицями в NumPy: створював вектори, транспонував їх, перевіряв ортогональність, знаходив унікальні елементи та виконував базову алгебру — додавання, множення, нормалізацію, скалярні добутки. Далі перейшов до матриць: генерував випадкові, обчислював визначник, обернену матрицю, розв’язував систему лінійних рівнянь, виконував множення, транспонування, перевіряв симетричність, слід, степінь та сортування. У результаті побачив, як швидко NumPy дозволяє виконувати всі ключові лінійні операції без зайвого коду, а робота допомогла закріпити розуміння базових інструментів, на яких тримається вся сучасна наука про дані та машинне навчання.
